# %%
import pandas as pd

# %%
data = pd.read_csv('data/high_sampling_rate.txt', names=["Time(ms)","415nm","445nm","480nm","515nm","555nm","590nm","630nm","680nm","NIR","CLEAR","LEDNum"])

data
# Out:
#      Time(ms)  415nm  445nm  480nm  515nm  555nm  590nm  630nm  680nm   NIR  \
# 0      175910     90    125    122    107     99    111    127    115  1273
# 1      175910      3      3      4      3      3      7     17     29    56
# 2      176643     44     40     45     39     49     72   1316   1033   146
# 3      176643     27     24     29     27     23    233   1118    131   134
# 4      176643     27     20     36     23    168   1181    243     61   134
# ..        ...    ...    ...    ...    ...    ...    ...    ...    ...   ...
# 820    236038     87    123    120    106     98    111    127    118  1269
# 821    236038      3      4      4      4      4      7     19     34    58
# 822    236772     44     40     44     39     48     71   1274   1024   149
# 823    236772     26     24     28     26     22    215   1075    132   130
# 824    236772     23     17     29     19    129    933    206     57   118
#
#      CLEAR  LEDNum
# 0     1530       8
# ...

# %%
data
# Out:
#      Time(ms)  415nm  445nm  480nm  515nm  555nm  590nm  630nm  680nm   NIR  \
# 0      175910     90    125    122    107     99    111    127    115  1273
# 1      175910      3      3      4      3      3      7     17     29    56
# 2      176643     44     40     45     39     49     72   1316   1033   146
# 3      176643     27     24     29     27     23    233   1118    131   134
# 4      176643     27     20     36     23    168   1181    243     61   134
# ..        ...    ...    ...    ...    ...    ...    ...    ...    ...   ...
# 820    236038     87    123    120    106     98    111    127    118  1269
# 821    236038      3      4      4      4      4      7     19     34    58
# 822    236772     44     40     44     39     48     71   1274   1024   149
# 823    236772     26     24     28     26     22    215   1075    132   130
# 824    236772     23     17     29     19    129    933    206     57   118
#
#      CLEAR  LEDNum
# 0     1530       8
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

y = data['630nm'][:40]
x = np.arange(len(y))
# x = data['Time(ms)'][:len(y)]
# cs = CubicSpline(x, y)
plt.plot(x, y, marker='o', linestyle='-', color='r')
plt.show()
